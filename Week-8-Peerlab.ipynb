# %%
import pandas as pd

# %%
Business=[{'product_id':23, 'name':'computer', 'wholesale_price': 500, 'retail_price':1000, 'sales':100}, 
{'product_id':96, 'name':'Python Workout', 'wholesale_price': 35,'retail_price':75, 'sales':1000},
{'product_id':97, 'name':'Pandas Workout', 'wholesale_price': 35, 'retail_price':75, 'sales':500},
{'product_id':15, 'name':'banana', 'wholesale_price': 0.5,'retail_price':1, 'sales':200},
{'product_id':87, 'name':'sandwich', 'wholesale_price': 3,'retail_price':5, 'sales':300}]

# %%
df=pd.DataFrame(Business)
df
# Out:
#    product_id            name  wholesale_price  retail_price  sales
# 0          23        computer            500.0          1000    100
# 1          96  Python Workout             35.0            75   1000
# 2          97  Pandas Workout             35.0            75    500
# 3          15          banana              0.5             1    200
# 4          87        sandwich              3.0             5    300

# %%
df.set_index('product_id', inplace=True)
df
# Out:
#                       name  wholesale_price  retail_price  sales
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300

# %%
df['net_revenue_per_product'] = (df['retail_price'] - df['wholesale_price']) * df['sales']
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product
# product_id
# 23                          50000.0
# 96                          40000.0
# 97                          20000.0
# 15                            100.0
# 87                            600.0

# %% [markdown]
# # How much total net revenue you received from all of these sales?

# %%
df['net_revenue_per_product'].sum()
# Out:
# 110700.0

# %% [markdown]
# # What product is product retail price more than twice the wholesale price?

# %%
df['Double Goods']=df['retail_price']>df['wholesale_price']*2
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product  Double Goods
# product_id
# 23                          50000.0         False
# 96                          40000.0          True
# 97                          20000.0          True
# 15                            100.0         False
# 87                            600.0         False

# %% [markdown]
# # How much did the store make from food vs. computers vs. books?

# %%
food=df[3:5]['net_revenue_per_product'].sum()

# %%
computers=df[:1]['net_revenue_per_product'].sum()

# %%
books=df[1:3]['net_revenue_per_product'].sum()

# %%
print(f'net_revenue from food:{food}')
print(f'net_revenue from computers:{computers}')
print(f'net_revenue from books:{books}')
# Out:
# net_revenue from food:700.0
# net_revenue from computers:50000.0
# net_revenue from books:60000.0

# %% [markdown]
# #  Because your store is doing so well, you’re able to negotiate a 30% discount on the wholesale price of goods. Calculate the new net revenue

# %%
df['New_wholesale_price']=df['wholesale_price']*0.7
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product  Double Goods  New_wholesale_price
# product_id
# 23                          50000.0         False               350.00
# 96                          40000.0          True                24.50
# 97                          20000.0          True                24.50
# 15                            100.0         False                 0.35
# 87                            600.0         False                 2.10

# %%
df['new_net_revenue'] = (df['retail_price'] - df['New_wholesale_price']) * df['sales']
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product  Double Goods  New_wholesale_price  \
# product_id
# 23                          50000.0         False               350.00
# 96                          40000.0          True                24.50
# 97                          20000.0          True                24.50
# 15                            100.0         False                 0.35
# 87                            600.0         False                 2.10
#
#             new_net_revenue
# product_id
# 23                  65000.0
# 96                  50500.0
# 97                  25250.0
# 15                    130.0
# 87                    870.0

# %%
df['new_net_revenue'].sum()
# Out:
# 141750.0
